# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('все_данные.csv')
df
# Out:
#                           регион  кол-во человек на 1 янв 22 года  \
# 0           Российская Федеpация                        145557576
# 1           Белгородская область                          1531917
# 2               Брянская область                          1168771
# 3           Владимирская область                          1323659
# 4            Воронежская область                          2287678
# ..                           ...                              ...
# 83              Амурская область                           772525
# 84           Магаданская область                           137767
# 85           Сахалинская область                           484177
# 86  Еврейская автономная область                           153831
# 87    Чукотский автономный округ                            50040
#
#    площадь тер-рии плотность населения на 1 янв 22 года распределение дотаций  \
# 0          17125,2                          8,499613202           758580846,2
# ...

# %%
op = df.columns
op
# Out:
# Index(['регион', 'кол-во человек на 1 янв 22 года', 'площадь тер-рии',
#        'плотность населения на 1 янв 22 года', 'распределение дотаций',
#        'Сколько нужно выделять дотация для выравнивания бюджета',
#        'сколько нужно в деньгах всего', 'Процент людей за чертой бедности',
#        'прожиточный минимум (на 2022 год)', 'средняя зп в месяц (2022)'],
#       dtype='object')

# %%
df
# Out:
#                           регион  кол-во человек на 1 янв 22 года  \
# 0           Российская Федеpация                        145557576
# 1           Белгородская область                          1531917
# 2               Брянская область                          1168771
# 3           Владимирская область                          1323659
# 4            Воронежская область                          2287678
# ..                           ...                              ...
# 83              Амурская область                           772525
# 84           Магаданская область                           137767
# 85           Сахалинская область                           484177
# 86  Еврейская автономная область                           153831
# 87    Чукотский автономный округ                            50040
#
#    площадь тер-рии плотность населения на 1 янв 22 года распределение дотаций  \
# 0          17125,2                          8,499613202           758580846,2
# ...

# %%
a = list(df.to_numpy())
l = []
for i in a:
    p = []
    i = list(i)
    for j in i:
        try:
            j = j.replace(',', '.')
            j = float(j)
        except:
            pass
        p.append(j)
    l.append(p)
l = np.array(l)
df = pd.DataFrame(l, columns = op)
for i in range(1, len(op)):
    df[op[i]] = df[op[i]].astype(float)

# %%
df
# Out:
#                           регион  кол-во человек на 1 янв 22 года  \
# 0           Российская Федеpация                      145557576.0
# 1           Белгородская область                        1531917.0
# 2               Брянская область                        1168771.0
# 3           Владимирская область                        1323659.0
# 4            Воронежская область                        2287678.0
# ..                           ...                              ...
# 83              Амурская область                         772525.0
# 84           Магаданская область                         137767.0
# 85           Сахалинская область                         484177.0
# 86  Еврейская автономная область                         153831.0
# 87    Чукотский автономный округ                          50040.0
#
#     площадь тер-рии  плотность населения на 1 янв 22 года  \
# 0           17125.2                              8.499613
# ...

# %%
df.fillna(value = 0)
# Out:
#                           регион  кол-во человек на 1 янв 22 года  \
# 0           Российская Федеpация                      145557576.0
# 1           Белгородская область                        1531917.0
# 2               Брянская область                        1168771.0
# 3           Владимирская область                        1323659.0
# 4            Воронежская область                        2287678.0
# ..                           ...                              ...
# 83              Амурская область                         772525.0
# 84           Магаданская область                         137767.0
# 85           Сахалинская область                         484177.0
# 86  Еврейская автономная область                         153831.0
# 87    Чукотский автономный округ                          50040.0
#
#     площадь тер-рии  плотность населения на 1 янв 22 года  \
# 0           17125.2                              8.499613
# ...

# %%
df.at[0, 'сколько нужно в деньгах всего'] = np.array(list(df['сколько нужно в деньгах всего'])[1:]).sum()
df.at[0, 'Сколько нужно выделять дотация для выравнивания бюджета'] = np.array(list(df['Сколько нужно выделять дотация для выравнивания бюджета'])[1:]).sum()

# %%
df
# Out:
#                           регион  кол-во человек на 1 янв 22 года  \
# 0           Российская Федеpация                      145557576.0
# 1           Белгородская область                        1531917.0
# 2               Брянская область                        1168771.0
# 3           Владимирская область                        1323659.0
# 4            Воронежская область                        2287678.0
# ..                           ...                              ...
# 83              Амурская область                         772525.0
# 84           Магаданская область                         137767.0
# 85           Сахалинская область                         484177.0
# 86  Еврейская автономная область                         153831.0
# 87    Чукотский автономный округ                          50040.0
#
#     площадь тер-рии  плотность населения на 1 янв 22 года  \
# 0           17125.2                              8.499613
# ...

# %%
# !pip install scikit-learn

# %%
import pandas as pd
import numpy as np

# %%
sf = pd.read_csv('недообр.csv')
sf
# Out:
#      Год  Численность  Средний возраст Плотность населения Площадь  \
# 0   1992      3164219                0         1,336918624  2366,8
# 1   1993      3160594                0          1,33538702  2366,8
# 2   1994      3139464                0         1,326459354  2366,8
# 3   1995      3113809                0         1,315619824  2366,8
# 4   1996      3099424                0         1,309541998  2366,8
# 5   1997      3085791                0           1,3037819  2366,8
# 6   1998      3067863                0         1,296207115  2366,8
# 7   1999      3048716                0         1,288117289  2366,8
# 8   2000      3022092                0         1,276868345  2366,8
# 9   2001      3000891                0         1,267910681  2366,8
# 10  2002      2981746                0           1,2598217  2366,8
# 11  2003      2961871                0         1,251424286  2366,8
# 12  2004      2931905                0         1,238763309  2366,8
# ...

# %%
a = list(sf['Площадь'])
l = []
for i in a:
    try:
        i = i.replace(',', '.')
        i = float(i)
    except:
        pass
    l.append(i)
l = np.array(l)
sf['Площадь'] = np.array(l)
sf['Численность'] = sf['Численность'].astype(int)

# %%
sf
# Out:
#      Год  Численность  Средний возраст Плотность населения  Площадь  \
# 0   1992      3164219                0         1,336918624   2366.8
# 1   1993      3160594                0          1,33538702   2366.8
# 2   1994      3139464                0         1,326459354   2366.8
# 3   1995      3113809                0         1,315619824   2366.8
# 4   1996      3099424                0         1,309541998   2366.8
# 5   1997      3085791                0           1,3037819   2366.8
# 6   1998      3067863                0         1,296207115   2366.8
# 7   1999      3048716                0         1,288117289   2366.8
# 8   2000      3022092                0         1,276868345   2366.8
# 9   2001      3000891                0         1,267910681   2366.8
# 10  2002      2981746                0           1,2598217   2366.8
# 11  2003      2961871                0         1,251424286   2366.8
# 12  2004      2931905                0         1,238763309   2366.8
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.bar(sf["Год"], sf["Численность"])
plt.show()

# %%
sns.set_theme(style="darkgrid")

# %%
sns.barplot(x = sf["Год"], y = sf["Численность"])
plt.xticks(rotation = 90)
plt.ylim(2700000, 3200000)
# Out:
# (2700000.0, 3200000.0)

# %%
df1 = pd.read_csv("недообр.csv")
df2 = pd.read_csv("москва_по_годам.csv")
df1
# Out:
#      Год  Численность  Средний возраст Плотность населения Площадь  \
# 0   1992      3164219                0         1,336918624  2366,8
# 1   1993      3160594                0          1,33538702  2366,8
# 2   1994      3139464                0         1,326459354  2366,8
# 3   1995      3113809                0         1,315619824  2366,8
# 4   1996      3099424                0         1,309541998  2366,8
# 5   1997      3085791                0           1,3037819  2366,8
# 6   1998      3067863                0         1,296207115  2366,8
# 7   1999      3048716                0         1,288117289  2366,8
# 8   2000      3022092                0         1,276868345  2366,8
# 9   2001      3000891                0         1,267910681  2366,8
# 10  2002      2981746                0           1,2598217  2366,8
# 11  2003      2961871                0         1,251424286  2366,8
# 12  2004      2931905                0         1,238763309  2366,8
# ...

# %%
a = list(df1['Процент людей за чертой бедности'])
l = []
for i in a:
    try:
        i = i.replace(',', '.')
        i = float(i)
    except:
        pass
    l.append(i)
l = np.array(l)
df1['Процент людей за чертой бедности'] = np.array(l)

# %%
a = list(df2['процент людей за чертой бедности'])
l = []
for i in a:
    try:
        i = i.replace(',', '.')
        i = float(i)
    except:
        pass
    l.append(i)
l = np.array(l)
df2['процент людей за чертой бедности'] = np.array(l)

# %%
width = 0.3

a = list(df1["Процент людей за чертой бедности"])
b = list(df2["процент людей за чертой бедности"])
a = a[3:]
b = b[4:]
dt = []
for i in range(1995, 2023):
    dt.append(i)
dt = np.array(dt)
a = np.array(a)
b = np.array(b)
fig, ax = plt.subplots()
rects1 = ax.bar(dt - width/2, a, width, label='Красноярский край')
rects2 = ax.bar(dt + width/2, b, width, label='Москва')
plt.xlabel("Год")
plt.ylabel("Процент людей за чертой бедности")
ax.set_title('Процент людей за чертой бедности в Москве и Красноярском крае')
ax.legend()

# %%
a = list(df1['Плотность населения'])
l = []
for i in a:
    try:
        i = i.replace(',', '.')
        i = float(i)
    except:
        pass
    l.append(i)
l = np.array(l)
df1['Плотность населения'] = np.array(l)

# %%
sns.barplot(x = df1["Год"], y = df1["Плотность населения"])
plt.xticks(rotation = 90)
plt.ylim(df1["Плотность населения"].min() - 0.08, df1["Плотность населения"].max() + 0.08)
# Out:
# (1.115329136, 1.416918624)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("кк_по_годам.csv")

# %%
a = list(df1['Плотность населения'])
l = []
for i in a:
    try:
        i = i.replace(',', '.')
        i = float(i)
    except:
        pass
    l.append(i)
l = np.array(l)
df1['Плотность населения'] = np.array(l)
df1
# Out:
#      Год  Численность  Средний возраст  Плотность населения Площадь  \
# 0   1992      3164219                0             1.336919  2366,8
# 1   1993      3160594                0             1.335387  2366,8
# 2   1994      3139464                0             1.326459  2366,8
# 3   1995      3113809                0             1.315620  2366,8
# 4   1996      3099424                0             1.309542  2366,8
# 5   1997      3085791                0             1.303782  2366,8
# 6   1998      3067863                0             1.296207  2366,8
# 7   1999      3048716                0             1.288117  2366,8
# 8   2000      3022092                0             1.276868  2366,8
# 9   2001      3000891                0             1.267911  2366,8
# 10  2002      2981746                0             1.259822  2366,8
# 11  2003      2961871                0             1.251424  2366,8
# 12  2004      2931905                0             1.238763  2366,8
# ...

# %%
x = np.array(df1["Год"])
y = np.array(df1["Плотность населения"])
plt.plot(x, y)
plt.show()

# %%
model = np.poly1d(np.polyfit(x, y, 4))
polyline = np.linspace(1991, 2022, 31)
plt.plot(x, y)
plt.plot(polyline, model(polyline))
plt.title("Сравнение реальных данных и предсказанных")
plt.xlabel("год")
plt.ylabel("плотность населения")
plt.show()

# %%
from sklearn.metrics import mean_absolute_percentage_error as mpe
mpe(y, model(polyline))*100
# Out:
# 0.4144946970758151

# %%
a = list(df1['Процент людей за чертой бедности'])
l = []
for i in a:
    try:
        i = i.replace(',', '.')
        i = float(i)
    except:
        pass
    l.append(i)
l = np.array(l)
df1['Процент людей за чертой бедности'] = np.array(l)
df1
# Out:
#      Год  Численность  Средний возраст  Плотность населения Площадь  \
# 0   1992      3164219                0             1.336919  2366,8
# 1   1993      3160594                0             1.335387  2366,8
# 2   1994      3139464                0             1.326459  2366,8
# 3   1995      3113809                0             1.315620  2366,8
# 4   1996      3099424                0             1.309542  2366,8
# 5   1997      3085791                0             1.303782  2366,8
# 6   1998      3067863                0             1.296207  2366,8
# 7   1999      3048716                0             1.288117  2366,8
# 8   2000      3022092                0             1.276868  2366,8
# 9   2001      3000891                0             1.267911  2366,8
# 10  2002      2981746                0             1.259822  2366,8
# 11  2003      2961871                0             1.251424  2366,8
# 12  2004      2931905                0             1.238763  2366,8
# ...

# %%
x = np.array(list(df1["Год"])[3:] + [2023])
y = np.array(list(df1["Процент людей за чертой бедности"])[3:] + [17.4])
plt.xlabel("Год")
plt.ylabel("Процент людей за чертой бедности")
plt.plot(x, y)
plt.show()

# %%
a = list(df1['доходы на душу населения'])
l = []
for i in a:
    try:
        i = i.replace(',', '.')
        i = float(i)
    except:
        pass
    l.append(i)
l = np.array(l)
df1['доходы на душу населения'] = np.array(l)

# %%
x = np.array(list(df1["Год"])[16:])
y = np.array(list(df1["доходы на душу населения"])[16:])
plt.xlabel("Год")
plt.ylabel("Доходы на душу населения")
plt.title("Доходы на душу населения в Красноярском крае")
plt.plot(x, y)
plt.show()

# %%
df1.fillna(value = 0)
df1 = df1.drop(index = 17, axis = 0)
df1 = df1.drop(index = 21, axis = 0)
df1 = df1.drop(index = 29, axis = 0)
df1 = df1.drop(index = 27, axis = 0)

# %%
a = list(df1['доходы на душу населения'])
l = []
for i in a:
    try:
        i = i.replace(',', '.')
        i = float(i)
    except:
        pass
    l.append(i)
l = np.array(l)
df1['доходы на душу населения'] = np.array(l)
df1
# Out:
#      Год  Численность  Средний возраст  Плотность населения Площадь  \
# 0   1992      3164219                0             1.336919  2366,8
# 1   1993      3160594                0             1.335387  2366,8
# 2   1994      3139464                0             1.326459  2366,8
# 3   1995      3113809                0             1.315620  2366,8
# 4   1996      3099424                0             1.309542  2366,8
# 5   1997      3085791                0             1.303782  2366,8
# 6   1998      3067863                0             1.296207  2366,8
# 7   1999      3048716                0             1.288117  2366,8
# 8   2000      3022092                0             1.276868  2366,8
# 9   2001      3000891                0             1.267911  2366,8
# 10  2002      2981746                0             1.259822  2366,8
# 11  2003      2961871                0             1.251424  2366,8
# 12  2004      2931905                0             1.238763  2366,8
# ...

# %%
a = list(df1['доходы на душу населения'])[16:]
data = list(df1['Год'])[16:]
plt.plot(data, a)
plt.show()

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
x = np.array(list(df1["Год"])[16:])
y = np.array(list(df1["доходы на душу населения"])[16:])
plt.plot(x, y)

# %%
model = np.poly1d(np.polyfit(x, y, 4))

polyline = np.linspace(2008, 2022, 11)
plt.plot(x, y)
plt.plot(polyline, model(polyline))
plt.title("Сравнение реальных данных и предсказанных")
plt.xlabel("год")
plt.ylabel("реальный доход на душу населения")
plt.show()

# %%
from sklearn.metrics import mean_absolute_percentage_error as mpe

mpe(y, model(polyline))*100
# Out:
# 189.09836207915902

# %%
print(model(2024))
# Out:
# -23431.953125

# %%
x1 = np.array(df1["Год"]).reshape((-1, 1))
y1 = np.array(df1["Численность"])

# %%
model1 = LinearRegression().fit(x1, y1)

# %%
r = model1.score(x1, y1)
print(r)
# Out:
# 0.7832639028308168

# %%
y_pred = model1.predict(x1)
print(y_pred)
y_p = np.array(y_pred)
plt.title("Сравнение реальных данных и предсказанных")
plt.xlabel("год")
plt.ylabel("численность населения")
plt.plot(x1, y_p)
plt.plot(x1, y1)
plt.show()
# Out:
# [3113796.11736641 3102239.18968745 3090682.2620085  3079125.33432954
#  3067568.40665058 3056011.47897162 3044454.55129267 3032897.62361371
#  3021340.69593475 3009783.76825579 2998226.84057684 2986669.91289788
#  2975112.98521892 2963556.05753997 2951999.12986101 2940442.20218205
#  2928885.27450309 2905771.41914518 2894214.49146622 2882657.56378727
#  2859543.70842935 2847986.78075039 2836429.85307144 2824872.92539248
#  2813315.99771352 2790202.14235561 2767088.28699769]

# %%
x = np.array(list(df1["Год"])[16:])
y = np.array(list(df1["доходы на душу населения"])[16:])
plt.scatter(x, y)

# %%
df1
# Out:
#      Год  Численность  Средний возраст  Плотность населения Площадь  \
# 0   1992      3164219                0             1.336919  2366,8
# 1   1993      3160594                0             1.335387  2366,8
# 2   1994      3139464                0             1.326459  2366,8
# 3   1995      3113809                0             1.315620  2366,8
# 4   1996      3099424                0             1.309542  2366,8
# 5   1997      3085791                0             1.303782  2366,8
# 6   1998      3067863                0             1.296207  2366,8
# 7   1999      3048716                0             1.288117  2366,8
# 8   2000      3022092                0             1.276868  2366,8
# 9   2001      3000891                0             1.267911  2366,8
# 10  2002      2981746                0             1.259822  2366,8
# 11  2003      2961871                0             1.251424  2366,8
# 12  2004      2931905                0             1.238763  2366,8
# ...

# %%
x = np.array(df1["Год"]).reshape((-1, 1))
y = np.array(df1["Плотность населения"])
print(x)
print(y)
plt.plot(x, y)
plt.show()
# Out:
# [[1992]
#  [1993]
#  [1994]
#  [1995]
#  [1996]
#  [1997]
#  [1998]
#  [1999]
#  [2000]
#  [2001]
#  [2002]
#  [2003]
#  [2004]
#  [2005]
#  [2006]
#  [2007]
#  [2008]
#  [2010]
#  [2011]
#  [2012]
#  [2014]
#  [2015]
#  [2016]
#  [2017]
#  [2018]
#  [2020]
#  [2022]]
# [1.33691862 1.33538702 1.32645935 1.31561982 1.309542   1.3037819
#  1.29620712 1.28811729 1.27686835 1.26791068 1.2598217  1.25142429
#  1.23876331 1.22609853 1.21231832 1.20222452 1.19867036 1.19691313
#  1.19532914 1.19925469 1.20534477 1.2078642  1.21112472 1.21484747
#  1.2153528  1.21102544 1.20683032]

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression


p = PolynomialFeatures(degree = 4, include_bias = False, interaction_only=False)


pf = p.fit_transform(x.reshape((-1, 1)))
print(pf)

prm = LinearRegression()
prm.fit(pf, y)


#print(poly_reg_model.intercept_, poly_reg_model.coef_)
# Out:
# [[1.99200000e+03 3.96806400e+06 7.90438349e+09 1.57455319e+13]
#  [1.99300000e+03 3.97204900e+06 7.91629366e+09 1.57771733e+13]
#  [1.99400000e+03 3.97603600e+06 7.92821578e+09 1.58088623e+13]
#  [1.99500000e+03 3.98002500e+06 7.94014988e+09 1.58405990e+13]
#  [1.99600000e+03 3.98401600e+06 7.95209594e+09 1.58723835e+13]
#  [1.99700000e+03 3.98800900e+06 7.96405397e+09 1.59042158e+13]
#  [1.99800000e+03 3.99200400e+06 7.97602399e+09 1.59360959e+13]
#  [1.99900000e+03 3.99600100e+06 7.98800600e+09 1.59680240e+13]
#  [2.00000000e+03 4.00000000e+06 8.00000000e+09 1.60000000e+13]
#  [2.00100000e+03 4.00400100e+06 8.01200600e+09 1.60320240e+13]
#  [2.00200000e+03 4.00800400e+06 8.02402401e+09 1.60640961e+13]
#  [2.00300000e+03 4.01200900e+06 8.03605403e+09 1.60962162e+13]
#  [2.00400000e+03 4.01601600e+06 8.04809606e+09 1.61283845e+13]
#  [2.00500000e+03 4.02002500e+06 8.06015012e+09 1.61606010e+13]
#  [2.00600000e+03 4.02403600e+06 8.07221622e+09 1.61928657e+13]
# ...

# %%
y_predicted = prm.predict(pf)

plt.xlabel("Год")
plt.ylabel("Плотность населения")

plt.title("Сравнение реальных данных и предсказанных")
plt.plot(x, y, label='Реальные данные')
plt.plot(x, y_predicted, color='orange', label='Предсказанные данные')
plt.show()

# %%
from sklearn.metrics import mean_absolute_percentage_error as mape
mape(y_predicted, x)*100
# Out:
# 160797.98734822305
